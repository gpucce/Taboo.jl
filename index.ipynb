# %% [markdown]
# # Taboo
#
# > Taboo in python and julia

# %% [markdown]
# Build cards using Wikipedia and draw them.

# %% [markdown]
# ## How to use

# %%
from Taboo.core import draw_card, load_taboo_words, add_taboo_words

# %%
print("organic farming")
Image.open("./temp_output/111_image_from__['a realistic representation of the meaning of organic farming, digital art, 4K, high quality']__.png")
# Out:
# organic farming
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
print("organic farming")
im = draw_card("./temp_output/111_image_from__['a realistic representation of the meaning of organic farming, digital art, 4K, high quality']__.png")
im
# Out:
# organic farming
# <PIL.Image.Image image mode=RGBA size=420x420>

# %%
taboo_words = load_taboo_words("./taboo_cards/test_organic_farming.json")
taboo_words
# Out:
# {'organic farming': ['random_word 1',
#   'random_word 2',
#   'random_word 3',
#   'random_word 4',
#   'random_word 5']}

# %%
add_taboo_words(im, taboo_words)
# Out:
# <PIL.Image.Image image mode=RGBA size=420x420>
