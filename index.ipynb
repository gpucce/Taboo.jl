# %% [markdown]
# # Taboo

# %% [markdown]
# Taboo in python and Julia.
#
# Build cards using Wikipedia and draw them.
#
# Check the [docs](https://gpucce.github.io/Taboo.jl/) and see how it works.

# %%
import json
from PIL import Image
from Taboo import draw_card, load_taboo_words, add_taboo_words
from Taboo import create_from_scratch

# %%
im_list = create_from_scratch("random walk", "en")
im_list[1]
# Out:
# <PIL.Image.Image image mode=RGBA size=420x420>

# %% [markdown]
# ## The steps to create each card

# %%
print("organic farming")
Image.open("./test_data/raw_images/organic_farming_raw.png")
# Out:
# organic farming
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
im = draw_card("./test_data/raw_images/organic_farming_raw.png")
im
# Out:
# <PIL.Image.Image image mode=RGBA size=420x420>

# %%
taboo_words = load_taboo_words("./test_data/taboo_cards/Organic farming.json")["cards"]
taboo_words[:2]
# Out:
# [{'Manure': ['Organic matter',
#    'Organic fertilizer',
#    'Agriculture',
#    'Feces',
#    'Compost',
#    'Green manure',
#    'Soil fertility',
#    'Nutrient',
#    'Nitrogen',
#    'Bacteria']},
#  {'Green manure': ['Agriculture',
#    'Biomass (ecology)',
#    'Manure',
#    'Soil organic matter',
#    'Legume',
#    'Organic farming',
#    'Intensive farming']}]

# %%
add_taboo_words(im, taboo_words[0])
# Out:
# <PIL.Image.Image image mode=RGBA size=420x420>

# %%
add_taboo_words(im, taboo_words[2])
# Out:
# <PIL.Image.Image image mode=RGBA size=420x420>
